# %% [markdown]
# # Python Practice Problems

# %% [markdown]
# ### 1. Find the Largest of Two Numbers
# **Task:** Given two numbers, find the larger one.
# **Demo Input:**  5 and 6 <br>
# **Output:** 6

# %%
a = 5
b = 6

print(max(a,b))
# Out:
# 6

# %% [markdown]
# ### 2. Print Numbers from 1 to N
# **Task**: Given a number `n`, print all numbers from 1 to `n`. <br>
# **Demo Input**: `5`  <br>
# **Demo Output**:  1 2 3 4 5

# %%
def printNos(n):
    if n > 0:
        printNos(n-1)
        print(n, end='')

n = 10
print(nos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/2590118559.py in <cell line: 0>()
#       5
#       6 n = 10
# ----> 7 print(nos)
#
# NameError: name 'nos' is not defined

# %% [markdown]
# ### 3. Check if a Number is Positive or Negative
# **Task**: Determine if the input number is positive, negative, or zero.
# **Demo Input**: `-3`
# **Demo Output**: `The number is Negative`

# %%
number = int(input("Enter your number :"))

if number < 0:
    print("The number is Negative")

else :
    print("This number is Postive")

# %% [markdown]
# ### 4. Calculate the Sum of Digits
# **Task**: Given a number, find the sum of its digits.
# **Demo Input**: `123`
# **Demo Output**: `6`
# (Explanation: `1+2+3=6`)

# %%
num1 = int (input("Enter a num1: "))
num2 = int (input("Enter a num2: "))
num3 = int (input("Enter a num3: "))
operation = input("enter operation(+,-,*,/):")

if operation == "+":
    result = num1 + num2 + num3

else:
    result = "Invalid number"

print("Result:", result)
# Out:
# Enter a num1:  1
# Enter a num2:  2
# Enter a num3:  3
# enter operation(+,-,*,/): +
# Result: 6

# %% [markdown]
# ### 5. Find Factorial of a Number
# **Task**: Calculate the factorial of a given number.
# **Demo Input**: `4`
# **Demo Output**: `24`
# (Explanation: `4! = 4*3*2*1 = 24`)

# %%
num1 = int(input("Enter demo number"))
num2 = int(input("Enter demo number"))
num3 = int(input("Enter demo number"))
num4 = int(input("Enter demo number"))
operation = input ("Enter operation(+,-,*,/):")

if operation == "*":
    result = num1 * num2 * num3

else :
    result = "Invalid number"

print("Result:", result)
# Out:
# Enter demo number 4
# Enter demo number 3
# Enter demo number 2
# Enter demo number 1
# Enter operation(+,-,*,/): *
# Result: 24

# %% [markdown]
# ### 6. Count Occurrences of a Digit
# **Task**: Count how many times a specific digit appears max in a number.
# **Demo Input**:  1233321 <br>
# **Demo Output**: `3`  <br>
# (Explanation: `3` appears 3 times in `1233321`)

# %%
digit = int(input("Enter demo number"))
max_count = 0
max_digit = ''

# %% [markdown]
# ### 7. Find the GCD of Two Numbers
# **Task**: Find the greatest common divisor (GCD) of two numbers.
# **Demo Input**: 8 and 12 <br>
# **Demo Output**: `4`

# %%
a = 8
b = 12

while b!=0:
    a, b = b,a %b

print(a)

# %% [markdown]
# ### 8. Reverse a String
# **Task**: Reverse the given string.
# **Demo Input**: `"aiquest"`
# **Demo Output**: `"tseuqia"`

# %%
a = "aiqiuest"
reverse = a[::-1]
print(reverse)

# %% [markdown]
# ### 9. Check Armstrong Number
# **Task**: Check if a number is an Armstrong number (the sum of its digits raised to the power of the number of digits equals the number).
# **Demo Input**: `153`
# **Demo Output**: `153 is an Armstrong Number`
# (Explanation: \(1^3 + 5^3 + 3^3 = 153\))

# %%
num1 = int(input("Enter a number"))

sum = 0
temp = num
while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10

if num == num:
    print(num, "is an armstrong number")
else:
    print(num, "is not an armstrong number")
# Out:
# Enter a number 153
# 5 is an armstrong number

# %% [markdown]
# ### 10. Generate a Pattern
# **Task**: Print a pyramid pattern with `n` rows.
# **Demo input:** 4 <br>
# **Output:** You will see the pyramid pattern with 4 rows

# %% [markdown]
# # Good Luck!
